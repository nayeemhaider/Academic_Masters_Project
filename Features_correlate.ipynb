# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Nayeem\\Desktop\\Project_Data\\Segmented_Data\\500 ms window\\Hand\\p1_hand_train.csv")

# %%
data.rename(columns={'#->Timestamp':'Timestamp'}, inplace=True)
data.rename(columns={'label':'Activity'}, inplace=True)

# %%
X = data.drop("Activity", axis=1)  # dropping target column
y = data["Activity"] # target column

# %%
data.head()
# Out:
#    Timestamp       Activity  TYPE_ACCELEROMETER-Xmean  \
# 0      0.762          Stand                 -0.136462
# 1      2.975          Stand                  1.905298
# 2      5.193          Stand                  5.872012
# 3      7.401  Start to walk                  4.534131
# 4      9.606           Walk                  2.668567
#
#    TYPE_ACCELEROMETER-Ymean  TYPE_ACCELEROMETER-Zmean  TYPE_GYROSCOPE-Xmean  \
# 0                  3.095218                 10.652274             -0.437375
# 1                  1.962280                  9.063483              0.028345
# 2                  2.134665                  7.303265             -0.109488
# 3                  2.838559                  9.811429             -0.278015
# 4                  2.931451                  6.438477              0.135718
#
#    TYPE_GYROSCOPE-Ymean  TYPE_GYROSCOPE-Zmean  TYPE_ACCELEROMETER-Xvar  \
# 0             -0.526666             -1.504990                 0.009755
# ...

# %%
#get correlations of each features in dataset

corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

#plot heat map

g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
